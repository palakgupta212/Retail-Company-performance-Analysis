# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/retail_raw.csv')

# %%
df.head()
# Out:
#           OrderID        Date   Region         Category Sub-Category  \
# 0  CA-2024-100111  2024-01-01     West        Furniture    Bookcases
# 1  CA-2024-100112  2024-01-03     East       Technology       Phones
# 2  CA-2024-100113  2024-01-04  Central  Office Supplies       Labels
# 3  CA-2024-100114  2024-01-07    South       Technology  Accessories
# 4  CA-2024-100115  2024-01-08     West        Furniture       Chairs
#
#           Product   Sales  Quantity  Discount  Profit
# 0      Bookcase A  261.96         2       0.0   41.91
# 1         Phone X  731.94         3       0.2  219.58
# 2         Label Z   14.62         2       0.0    6.87
# 3  Mouse Wireless  243.16         5       0.1   30.92
# 4      Ergo Chair  957.58         7       0.3   90.75

# %%
# Plotting
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Retail Company Performance Dashboard", fontsize=16, fontweight='bold')

# Sales by Region
region_sales = df.groupby('Region')['Sales'].sum()
axs[0, 0].bar(region_sales.index, region_sales.values, color='skyblue')
axs[0, 0].set_title("Total Sales by Region")

# Pie Chart
axs[0, 1].pie(region_sales.values, labels=region_sales.index, autopct='%1.1f%%')
axs[0, 1].set_title("Sales Distribution by Region")

# Profit by Category
category_profit = df.groupby('Category')['Profit'].sum()
axs[1, 0].bar(category_profit.index, category_profit.values, color='seagreen')
axs[1, 0].set_title("Profit by Category")

# Monthly Trend
data["Date"] = pd.to_datetime(data["Date"])  # Add this line
data["Month"] = data["Date"].dt.to_period("M").astype(str)
monthly_sales = data.groupby("Month")["Sales"].sum()
axs[1, 1].plot(monthly_sales.index, monthly_sales.values, marker="o", color="coral")
axs[1, 1].set_title("Monthly Sales Trend")
axs[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig("retail_dashboard.png")
